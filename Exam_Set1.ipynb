# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
modf = pd.read_csv('Movie-Data.csv')
modf
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# question 1 top 10 records
modf.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
# question 2 print highest and least profit
rev = modf['Revenue (Millions)']
rev
# Out:
# 0      333.13
# 1      126.46
# 2      138.12
# 3      270.32
# 4      325.02
#         ...
# 995       NaN
# 996     17.54
# 997     58.01
# 998       NaN
# 999     19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
MaxRev = max(rev)

# %%
MaxRev
# Out:
# 936.63

# %%
MinRev = min(rev)
MinRev
# Out:
# 0.0

# %%
# question 3 Name of the movie which has 0.0 revenue or budget
minrev = modf[modf['Revenue (Millions)']==0.0]

# %%
minrev
# Out:
#      Rank             Title                 Genre  \
# 231   232  A Kind of Murder  Crime,Drama,Thriller
#
#                                            Description      Director  \
# 231  In 1960s New York, Walter Stackhouse is a succ...  Andy Goddard
#
#                                                 Actors  Year  \
# 231  Patrick Wilson, Jessica Biel, Haley Bennett, V...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 231                 95     5.2   3305                 0.0       50.0

# %%
# question 4 total profit in each year made by all movies

years = modf['Year']

# %%
years
# Out:
# 0      2014
# 1      2012
# 2      2016
# 3      2016
# 4      2016
#        ...
# 995    2015
# 996    2007
# 997    2008
# 998    2014
# 999    2016
# Name: Year, Length: 1000, dtype: int64

# %%
uyear = years.unique()
uyear
# Out:
# array([2014, 2012, 2016, 2015, 2007, 2011, 2008, 2006, 2009, 2010, 2013])

# %%
uyear.sort()
uyear
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
uyear.dtype
type(uyear)
# Out:
# numpy.ndarray

# %%
uyear.sum()
# Out:
# 22121

# %%
RevOf2006 = modf[modf['Year']==2006]
RevOf2006
# Out:
#      Rank                                        Title  \
# 64     65                                 The Prestige
# 78     79   Pirates of the Caribbean: Dead Man's Chest
# 99    100                                 The Departed
# 113   114                                          300
# 164   165                                Casino Royale
# 221   222                                         Cars
# 230   231                              Pan's Labyrinth
# 232   233                                   Apocalypto
# 246   247                              Children of Men
# 297   298                        The Devil Wears Prada
# 308   309        The Fast and the Furious: Tokyo Drift
# 320   321                                      Step Up
# 445   446                                  Silent Hill
# 471   472                             Marie Antoinette
# 476   477                          The Lives of Others
# 530   531                                  A Good Year
# ...

# %%
rev2006 = RevOf2006['Revenue (Millions)']
rev2006
# Out:
# 64      53.08
# 78     423.03
# 99     132.37
# 113    210.59
# 164    167.01
# 221    244.05
# 230     37.62
# 232     50.86
# 246     35.29
# 297    124.73
# 308     62.49
# 320     65.27
# 445     46.98
# 471     15.96
# 476     11.28
# 530      7.46
# 532       NaN
# 550    118.68
# 559      0.44
# 573     59.89
# 593      2.34
# 626    234.36
# 632      2.20
# 640    162.59
# 669     57.37
# 715    197.99
# 727     39.83
# 733    217.54
# 773     42.27
# 774     10.14
# 796      5.48
# 815     88.50
# 830     70.27
# 858     41.78
# 869    133.38
# 885     34.30
# 897      2.28
# 901     34.01
# 908      7.77
# 918      2.21
# 924    200.07
# 935    148.21
# 959     22.49
# 965       NaN
# Name: Revenue (Millions), dtype: float64

# %%
rev2006.sum()
# Out:
# 3624.4599999999996

# %%
revlist = []
revdict = {}
for year in uyear:
    RevYear = modf[modf['Year']==year]
    revOfYear = RevYear['Revenue (Millions)']
    print(f"Total Revenue of the year {year} is {revOfYear.sum()} Millions")
    revlist.append(revOfYear.sum())
    revdict[year] = revOfYear.sum()
# Out:
# Total Revenue of the year 2006 is 3624.4599999999996 Millions
# Total Revenue of the year 2007 is 4306.2300000000005 Millions
# Total Revenue of the year 2008 is 5053.220000000001 Millions
# Total Revenue of the year 2009 is 5292.26 Millions
# Total Revenue of the year 2010 is 5989.650000000001 Millions
# Total Revenue of the year 2011 is 5431.96 Millions
# Total Revenue of the year 2012 is 6910.289999999999 Millions
# Total Revenue of the year 2013 is 7666.72 Millions
# Total Revenue of the year 2014 is 7997.4 Millions
# Total Revenue of the year 2015 is 8854.119999999999 Millions
# Total Revenue of the year 2016 is 11211.65 Millions

# %%
# question 5 line graph of title and runtime
x = modf['Title']
y = modf['Runtime (Minutes)']
plt.plot(x,y)
plt.show()

# %%
# question 6  maximum profit in which year
revlist
# Out:
# [3624.4599999999996,
#  4306.2300000000005,
#  5053.220000000001,
#  5292.26,
#  5989.650000000001,
#  5431.96,
#  6910.289999999999,
#  7666.72,
#  7997.4,
#  8854.119999999999,
#  11211.65]

# %%
# question 7 maximum profit in which year
maxrev = revlist[0]
for revn in revlist:
    if maxrev<revn:
        maxrev=revn
        
print(maxrev)
# Out:
# 11211.65

# %%
revlist = []
revdist ={}
for year in uyear:
    RevYear = modf[modf['Year']==year]
    revOfYear = RevYear['Revenue (Millions)']
    print(f"Total Revenue of the year {year} is {revOfYear.sum()} Millions")
    revlist.append(revOfYear.sum())
    revdist[year]=revOfYear
    
revMaxYear = revdict[uyear[0]]
for k,v in revdict.items():
    if revMaxYear<v:
        revMaxYear = v
        maxYear = k
        
print(f"Maximum Revenue made by movies {revMaxYear} in year {k}")
# Out:
# Total Revenue of the year 2006 is 3624.4599999999996 Millions
# Total Revenue of the year 2007 is 4306.2300000000005 Millions
# Total Revenue of the year 2008 is 5053.220000000001 Millions
# Total Revenue of the year 2009 is 5292.26 Millions
# Total Revenue of the year 2010 is 5989.650000000001 Millions
# Total Revenue of the year 2011 is 5431.96 Millions
# Total Revenue of the year 2012 is 6910.289999999999 Millions
# Total Revenue of the year 2013 is 7666.72 Millions
# Total Revenue of the year 2014 is 7997.4 Millions
# Total Revenue of the year 2015 is 8854.119999999999 Millions
# Total Revenue of the year 2016 is 11211.65 Millions
# Maximum Revenue made by movies 11211.65 in year 2016

# %%
#question 7 shape and size
modf.size
# Out:
# 12000

# %%
modf.shape
# Out:
# (1000, 12)

# %%
# question 8 find duplicates and remove it
modf.duplicated().value_counts()
# Out:
# False    1000
# dtype: int64

# %%
# question 9 fill the null value with average value
modf.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
rev = modf['Revenue (Millions)']
rev.mean()
# Out:
# 82.95637614678897

# %%
rev.fillna(rev.mean(),inplace=True)

# %%
    rev
# Out:
# 0      333.130000
# 1      126.460000
# 2      138.120000
# 3      270.320000
# 4      325.020000
#           ...
# 995     82.956376
# 996     17.540000
# 997     58.010000
# 998     82.956376
# 999     19.640000
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
modf.isnull().sum()
# Out:
# Rank                   0
# Title                  0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# dtype: int64
